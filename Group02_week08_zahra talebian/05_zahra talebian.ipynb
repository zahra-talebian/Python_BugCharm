# %%
import numpy as np

# %%
import pandas as pd

# %%
daramad=np.random.randint(5000,15000,12)
daramad
# Out:
# array([14613, 10374,  9514, 12954, 12880, 12210,  6062,  7659, 12229,
#        13810,  6684,  8227], dtype=int32)

# %%
hazineh=np.random.randint(3000,12000,12)
hazineh
# Out:
# array([11465,  4317,  9769,  3313, 10038,  4632,  3605,  5597,  7762,
#         9506, 10127,  8674], dtype=int32)

# %%
profit=daramad-hazineh
profit
# Out:
# array([ 3148,  6057,  -255,  9641,  2842,  7578,  2457,  2062,  4467,
#         4304, -3443,  -447], dtype=int32)

# %%
profit_max=np.max(profit)
profit_max
# Out:
# np.int32(9641)

# %%
loss=np.where(profit<0)
loss
# Out:
# (array([ 2, 10, 11]),)
