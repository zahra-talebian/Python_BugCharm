# %%
import pandas as pd

# %%
import numpy as np

# %%
array_x=np.array([10,20,13,17,15,9,1,12,23])
array_y=np.array([6,7,13,26,14,18,2,51,62])

# %%
np.where(array_x>array_y)
# Out:
# (array([0, 1, 4]),)

# %%
np.where(array_x==array_y)
# Out:
# (array([2]),)
