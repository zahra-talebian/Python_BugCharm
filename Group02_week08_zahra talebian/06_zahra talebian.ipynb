# %%
import numpy as np

# %%
import pandas as pd

# %%
fruits = [
    "Apple","Banana","Orange","Mango","Grape","Strawberry",
    "Pineapple","Watermelon","Melon","Peach","Pear","Cherry",
    "Lemon","Lime","Kiwi","Blueberry","Raspberry","Blackberry",
    "Fig","Date","Pomegranate","Coconut","Papaya","Guava",
    "Apricot","Plum","Nectarine","Avocado","Cranberry","Passion Fruit"]

# %%
sales_fruits=pd.Series(np.random.randint(100, 1000, 30),index=fruits)
sales_fruits
# Out:
# Apple            492
# Banana           529
# Orange           388
# Mango            843
# Grape            656
# Strawberry       732
# Pineapple        728
# Watermelon       912
# Melon            440
# Peach            801
# Pear             350
# Cherry           692
# Lemon            697
# Lime             740
# Kiwi             819
# Blueberry        433
# Raspberry        164
# Blackberry       791
# Fig              615
# Date             981
# Pomegranate      774
# Coconut          303
# Papaya           360
# Guava            492
# Apricot          238
# Plum             132
# Nectarine        397
# Avocado          553
# Cranberry        584
# Passion Fruit    894
# dtype: int32

# %%
sales_fruits.max()
# Out:
# np.int32(981)

# %%
sahm = (sales_fruits /sales_fruits.sum())*100
sahm
# Out:
# Apple            2.806617
# Banana           3.017684
# Orange           2.213349
# Mango            4.808899
# Grape            3.742156
# Strawberry       4.175699
# Pineapple        4.152881
# Watermelon       5.202510
# Melon            2.509983
# Peach            4.569310
# Pear             1.996577
# Cherry           3.947519
# Lemon            3.976041
# Lime             4.221335
# Kiwi             4.671991
# Blueberry        2.470051
# Raspberry        0.935539
# Blackberry       4.512265
# Fig              3.508272
# Date             5.596121
# Pomegranate      4.415288
# Coconut          1.728465
# Papaya           2.053622
# Guava            2.806617
# Apricot          1.357673
# Plum             0.752995
# Nectarine        2.264689
# Avocado          3.154592
# Cranberry        3.331432
# Passion Fruit    5.099829
# dtype: float64

# %%
sales_fruits.mean()
remove_fruits = [sales_fruits.mean()>sales_fruits]
remove_fruits
# Out:
# [Apple             True
#  Banana            True
#  Orange            True
#  Mango            False
#  Grape            False
#  Strawberry       False
#  Pineapple        False
#  Watermelon       False
#  Melon             True
#  Peach            False
#  Pear              True
#  Cherry           False
#  Lemon            False
#  Lime             False
#  Kiwi             False
#  Blueberry         True
#  Raspberry         True
#  Blackberry       False
#  Fig              False
#  Date             False
#  Pomegranate      False
#  Coconut           True
#  Papaya            True
#  Guava             True
#  Apricot           True
#  Plum              True
#  Nectarine         True
#  Avocado           True
#  Cranberry         True
#  Passion Fruit    False
#  dtype: bool]
