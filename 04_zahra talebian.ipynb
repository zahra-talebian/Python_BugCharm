# %%
import numpy as np

# %%
import pandas as pd

# %%
array_04=np.random.randint(0,21,size=(5,30))
array_04
# Out:
# array([[20, 10,  4,  4, 16,  2,  0, 10,  5,  3,  5,  0, 15,  6, 10,  1,
#          6,  1, 12,  3, 10,  9,  9,  7, 16, 14,  9,  0, 10,  1],
#        [ 4, 16,  6,  7, 11, 19,  6, 12,  7,  7, 15,  0, 19,  3,  2, 14,
#         14,  7,  1, 19, 12,  9, 12,  6,  1,  4, 11,  5,  3, 17],
#        [10, 16,  3,  7, 19,  8, 14, 13, 11, 16,  4, 14, 11,  1,  5,  9,
#         14,  6, 12, 11, 11, 12,  9, 13, 12,  5,  3,  8, 20,  1],
#        [10, 12,  2,  6, 16,  1, 12,  7,  5, 18,  5,  1, 19,  7,  9,  7,
#          8, 10,  0, 20,  0, 10,  1,  1, 18, 18, 10, 11,  0, 12],
#        [ 8,  5, 20,  1, 10, 12, 10, 20, 13, 14, 20,  2, 20,  5,  6, 11,
#         15, 10, 10, 18, 15, 14, 10,  0,  9, 19, 13,  2,  8,  4]],
#       dtype=int32)

# %%
student_avg = array_04.mean(axis=1)
lesson_avg = array_04.mean(axis=0)

# %%
lesson_grater=np.where(array_04>15,1,0)
np.where((array_04 > 15).sum(axis=1) >= 3)
(array_04 > 15).sum(axis=1)
# Out:
# array([3, 5, 4, 6, 6])

# %%
hardest_lesson = np.argmin(lesson_avg)
hardest_lesson
# Out:
# np.int64(11)
